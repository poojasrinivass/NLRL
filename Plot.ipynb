# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
import pylab as pl

# %%
blocks_5 = [0.747, -0.959, -0.96, -0.98]
blocks_6 = [0.607, -0.98, -0.98, -0.98]
blocks_7 = [0.407, -0.98, -0.98, -0.98]
shuffle_top = [0.847, -0.98, -0.785, -0.885]
trained = [0.844, 0.94, -0.822, 0.939]
index = ['NLRL', 'NN', 'Random', 'Q Learning']
df = pd.DataFrame({'5blocks': blocks_5,
                   '6blocks': blocks_6,
                   '7blocks': blocks_7,
                   'shuffle top2': shuffle_top,
                   'trained': trained}, index=index)
ax = df.plot.bar(rot=0)
pl.suptitle("Unstack")
# Out:
# Text(0.5,0.98,'Unstack')

# %%
blocks_5 = [0.915, -0.959, -0.948, -0.98]
blocks_6 = [0.891, -0.98, -0.98, -0.98]
blocks_7 = [0.868, -0.98, -0.98, -0.98]
swap_right2 = [ 0.913, -0.98, -0.24, -0.98]
columns = [0.897, -0.98, -0.215, -0.98]
trained = [ 0.91, 0.94,  -0.292, 1]
index = ['NLRL', 'NN', 'Random', 'Q Learning']
df = pd.DataFrame({'5blocks': blocks_5,
                   '6blocks': blocks_6,
                   '7blocks': blocks_7,
                   'swap right2': swap_right2,
                   '2columns': columns,
                   'trained': trained}, index=index)
ax = df.plot.bar(rot=0)
pl.suptitle("Stack")
# Out:
# Text(0.5,0.98,'Stack')

# %%
blocks_5 = [0.89, -0.98, -0.949, -0.98]
blocks_6 = [0.865, -0.98, -0.975, -0.98]
blocks_7 = [0.844, -0.98, -0.98, -0.98]
shuffle_top = [0.912, -0.98, -0.821, -0.516]
shuffle_middle = [0.914, -0.98, -0.853, -0.98]
trained = [0.915, 0.92, -0.837, 0.92]
index = ['NLRL', 'NN', 'Random', 'Q Learning']
df = pd.DataFrame({'5blocks': blocks_5,
                   '6blocks': blocks_6,
                   '7blocks': blocks_7,
                   'swap top': shuffle_top,
                   'swap middle': shuffle_middle,
                   'trained': trained}, index=index)
ax = df.plot.bar(rot=0)
pl.suptitle("On")
# Out:
# Text(0.5,0.98,'On')

# %%
top_left = [0.749, -0.98, -1.115, -0.98]
top_right = [0.809, -0.98, -0.966, -0.98]
center = [0.859, -0.917, -0.952, 0.599]
by6 = [0.841, -0.934, -1.101, -1.124]
by7 = [0.824, -1.122, -1.107, -1.126]
trained = [0.862, 0.877, -1.096, 0.878]
index = ['NLRL', 'NN', 'Random', 'Q Learning']
df = pd.DataFrame({'top left': top_left,
                   'top right': top_right,
                   'center': center,
                   '6 by 6': by6,
                   '7 by 7': by7,
                   'trained': trained}, index=index)
ax = df.plot.bar(rot=0)
pl.suptitle("Cliff Walking")
# Out:
# Text(0.5,0.98,'Cliff Walking')

# %%
top_left = [0.726, 0.836, -1.376, -0.98]
top_right = [0.834, 0.919, -1.089, -0.98]
center = [0.672, 0.859, -1.082, 0.876]
by6 = [0.345, -1.110, -0.907, -1.204]
by7 = [0.506, -1.161, -1.077, -1.204]
trained = [0.663, 0.649, -1.129, 0.7302]
index = ['NLRL', 'NN', 'Random', 'Q Learning']
df = pd.DataFrame({'top left': top_left,
                   'top right': top_right,
                   'center': center,
                   '6 by 6': by6,
                   '7 by 7': by7,
                   'trained': trained}, index=index)
ax = df.plot.bar(rot=0)
pl.suptitle("Windy Cliff Walking")
# Out:
# Text(0.5,0.98,'Windy Cliff Walking')
